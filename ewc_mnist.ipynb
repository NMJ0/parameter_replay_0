# %%
import torch
import torch.nn as nn
from os.path import expanduser
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from avalanche.benchmarks import nc_benchmark
from avalanche.training.supervised import EWC
from avalanche.models import as_multitask
from avalanche.evaluation.metrics import accuracy_metrics
from avalanche.logging import InteractiveLogger
from avalanche.training.plugins import EvaluationPlugin


class CustomMLP(nn.Module):
    """Custom MLP with 2 hidden layers (256 and 128)"""
    def __init__(self, num_classes=2):
        super().__init__()
        self.classifier = nn.Sequential(
            nn.Linear(784, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, num_classes)
        )
    
    def forward(self, x):
        x = x.view(x.size(0), -1)
        return self.classifier(x)


def main():
    
    scenario_name = "multitask_smnist"
    
    # EWC settings
    ewc_mode = "separate"  # Options: "separate", "online"
    ewc_lambda = 0.5  # Penalty hyperparameter for EWC
    decay_factor = 0.1  # Decay factor (only used when ewc_mode is "online")
    
    # Training settings
    learning_rate = 1e-3
    epochs = 5
    minibatch_size = 128
   
    
    # Device settings
    cuda_id = 0  # GPU id to use, set to -1 for CPU
    
    device = torch.device(cuda_id if torch.cuda.is_available() and cuda_id >= 0 else "cpu")
    print(f"Using device: {device}")
    
    # Create model with 2 hidden layers (256 and 128)
    model = CustomMLP(num_classes=2)
    model = as_multitask(model, "classifier")
    model.to(device)
    
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
    criterion = torch.nn.CrossEntropyLoss()
    
    # Create benchmark
    mnist_train = MNIST(
        root=expanduser("~") + "/.avalanche/data/mnist/",
        train=True,
        download=True,
        transform=ToTensor(),
    )
    mnist_test = MNIST(
        root=expanduser("~") + "/.avalanche/data/mnist/",
        train=False,
        download=True,
        transform=ToTensor(),
    )
    scenario = nc_benchmark(
        mnist_train,
        mnist_test,
        5,
        task_labels=True,
        seed=1234,
        class_ids_from_zero_in_each_exp=True,
    )
    
    # Setup evaluation plugin
    interactive_logger = InteractiveLogger()
    eval_plugin = EvaluationPlugin(
        accuracy_metrics(
            minibatch=True, epoch=True, experience=True, stream=True
        ),
        loggers=[interactive_logger],
    )
    
    if ewc_mode == 'separate':
        decay_factor = None
    
    strategy = EWC(
        model,
        optimizer,
        criterion,
        ewc_lambda,
        ewc_mode,
        decay_factor=decay_factor,
        train_epochs=epochs,
        device=device,
        train_mb_size=minibatch_size,
        evaluator=eval_plugin,
    )
  
    
    print("Starting experiment...")
    print(f"Scenario: {scenario_name}")
    print(f"EWC Mode: {ewc_mode}")
    print(f"EWC Lambda: {ewc_lambda}")
    print(f"Epochs per task: {epochs}")
    print("=" * 70)
    
    results = []
    for experience in scenario.train_stream:
        print(f"\nStart training on experience {experience.current_experience}")
        
        strategy.train(experience)
        
        print(f"End training on experience {experience.current_experience}")
        print("Computing accuracy on the test set")
        
        results.append(strategy.eval(scenario.test_stream[:]))
    
    print("\n" + "=" * 70)
    print("Experiment completed!")
    print("=" * 70)
    
    
    return results


if __name__ == "__main__":
    results = main()
# Out:
# Using device: cuda:0
# Starting experiment...
# Scenario: multitask_smnist
# EWC Mode: separate
# EWC Lambda: 0.5
# Epochs per task: 5
# ======================================================================
#
# Start training on experience 0
# -- >> Start of training phase << --
# 100%|██████████| 88/88 [00:03<00:00, 25.69it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4813
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5276
# 100%|██████████| 88/88 [00:03<00:00, 27.06it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4813
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4173
# 100%|██████████| 88/88 [00:03<00:00, 26.58it/s]
# Epoch 2 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4814
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.3701
# 100%|██████████| 88/88 [00:02<00:00, 29.96it/s]
# Epoch 3 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4899
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4331
# 100%|██████████| 88/88 [00:03<00:00, 26.95it/s]
# Epoch 4 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5610
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.6929
# -- >> End of training phase << --
# End training on experience 0
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 15/15 [00:00<00:00, 28.57it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6558
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 25.94it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4855
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 25.96it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4870
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 17/17 [00:00<00:00, 29.04it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5247
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 27.33it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4925
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task004 = 0.5276
#
# Start training on experience 1
# -- >> Start of training phase << --
# 100%|██████████| 93/93 [00:03<00:00, 24.39it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task001 = 0.4956
# 	Top1_Acc_MB/train_phase/train_stream/Task001 = 0.7273
# 100%|██████████| 93/93 [00:03<00:00, 25.82it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task001 = 0.4970
# 	Top1_Acc_MB/train_phase/train_stream/Task001 = 0.5152
# 100%|██████████| 93/93 [00:03<00:00, 24.38it/s]
# Epoch 2 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task001 = 0.5037
# 	Top1_Acc_MB/train_phase/train_stream/Task001 = 0.4545
# 100%|██████████| 93/93 [00:03<00:00, 26.60it/s]
# Epoch 3 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task001 = 0.5329
# 	Top1_Acc_MB/train_phase/train_stream/Task001 = 0.6667
# 100%|██████████| 93/93 [00:03<00:00, 27.31it/s]
# Epoch 4 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task001 = 0.5879
# 	Top1_Acc_MB/train_phase/train_stream/Task001 = 0.5152
# -- >> End of training phase << --
# End training on experience 1
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 15/15 [00:00<00:00, 30.91it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5534
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 33.09it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6281
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 29.01it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4870
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 17/17 [00:00<00:00, 28.65it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5247
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 29.20it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4925
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task004 = 0.5370
#
# Start training on experience 2
# -- >> Start of training phase << --
# 100%|██████████| 93/93 [00:04<00:00, 22.42it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task002 = 0.5906
# 	Top1_Acc_MB/train_phase/train_stream/Task002 = 0.7143
# 100%|██████████| 93/93 [00:04<00:00, 23.23it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task002 = 0.7496
# 	Top1_Acc_MB/train_phase/train_stream/Task002 = 0.7912
# 100%|██████████| 93/93 [00:03<00:00, 25.24it/s]
# Epoch 2 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task002 = 0.8797
# 	Top1_Acc_MB/train_phase/train_stream/Task002 = 0.9341
# 100%|██████████| 93/93 [00:03<00:00, 24.12it/s]
# Epoch 3 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task002 = 0.9393
# 	Top1_Acc_MB/train_phase/train_stream/Task002 = 0.9670
# 100%|██████████| 93/93 [00:03<00:00, 23.45it/s]
# Epoch 4 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task002 = 0.9608
# 	Top1_Acc_MB/train_phase/train_stream/Task002 = 0.9560
# -- >> End of training phase << --
# End training on experience 2
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 15/15 [00:00<00:00, 27.92it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5240
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 31.09it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7323
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 31.16it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.9700
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 17/17 [00:00<00:00, 29.33it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5247
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 26.43it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4925
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task004 = 0.6474
#
# Start training on experience 3
# -- >> Start of training phase << --
# 100%|██████████| 102/102 [00:04<00:00, 20.80it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task003 = 0.8033
# 	Top1_Acc_MB/train_phase/train_stream/Task003 = 0.8608
# 100%|██████████| 102/102 [00:04<00:00, 21.12it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task003 = 0.9510
# 	Top1_Acc_MB/train_phase/train_stream/Task003 = 0.9873
# 100%|██████████| 102/102 [00:04<00:00, 20.67it/s]
# Epoch 2 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task003 = 0.9663
# 	Top1_Acc_MB/train_phase/train_stream/Task003 = 0.9494
# 100%|██████████| 102/102 [00:04<00:00, 22.62it/s]
# Epoch 3 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task003 = 0.9700
# 	Top1_Acc_MB/train_phase/train_stream/Task003 = 0.9494
# 100%|██████████| 102/102 [00:04<00:00, 22.96it/s]
# Epoch 4 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task003 = 0.9712
# 	Top1_Acc_MB/train_phase/train_stream/Task003 = 0.9873
# -- >> End of training phase << --
# End training on experience 3
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 15/15 [00:00<00:00, 29.11it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5448
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 27.86it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6236
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 33.41it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.9715
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 17/17 [00:00<00:00, 31.41it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9663
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 25.41it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4925
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task004 = 0.7253
#
# Start training on experience 4
# -- >> Start of training phase << --
# 100%|██████████| 95/95 [00:04<00:00, 21.18it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task004 = 0.7525
# 	Top1_Acc_MB/train_phase/train_stream/Task004 = 0.9091
# 100%|██████████| 95/95 [00:04<00:00, 20.87it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task004 = 0.8956
# 	Top1_Acc_MB/train_phase/train_stream/Task004 = 0.9545
# 100%|██████████| 95/95 [00:04<00:00, 21.26it/s]
# Epoch 2 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task004 = 0.9462
# 	Top1_Acc_MB/train_phase/train_stream/Task004 = 1.0000
# 100%|██████████| 95/95 [00:04<00:00, 19.53it/s]
# Epoch 3 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task004 = 0.9654
# 	Top1_Acc_MB/train_phase/train_stream/Task004 = 0.9545
# 100%|██████████| 95/95 [00:04<00:00, 19.56it/s]
# Epoch 4 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task004 = 0.9704
# 	Top1_Acc_MB/train_phase/train_stream/Task004 = 1.0000
# -- >> End of training phase << --
# End training on experience 4
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 15/15 [00:00<00:00, 31.03it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5614
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 33.06it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5897
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 31.86it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.9649
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 17/17 [00:00<00:00, 30.08it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9635
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 16/16 [00:00<00:00, 29.46it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9819
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task004 = 0.8171
#
# ======================================================================
# Experiment completed!
# ======================================================================
